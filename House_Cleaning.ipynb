# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows',None)
pd.set_option("display.max_columns",None)

# %%
houses = pd.read_csv('houses.csv')

# %%
df = houses.copy()

# %%
df
# Out:
#                                           property_name  \
# 0        5 Bedroom House for sale in Sector 70A Gurgaon
# 1      5 Bedroom House for sale in Sector 21A Faridabad
# 2      10 Bedroom House for sale in Sushant Lok Phase 1
# 3        21 Bedroom House for sale in Sector 54 Gurgaon
# 4      12 Bedroom House for sale in Sushant Lok Phase 1
# 5      20 Bedroom House for sale in Sushant Lok Phase 1
# 6         5 Bedroom House for sale in Sector 66 Gurgaon
# 7              16 Bedroom House for sale in DLF Phase 1
# 8               6 Bedroom House for sale in DLF Phase 2
# 9       3 Bedroom House for sale in Sushant Lok Phase 1
# 10              4 Bedroom House for sale in DLF Phase 2
# 11              6 Bedroom House for sale in DLF Phase 4
# 12             13 Bedroom House for sale in DLF Phase 3
# 13              5 Bedroom House for sale in DLF Phase 1
# 14    5 Bedroom House for sale in B Block Sushant Lo...
# 15    6 Bedroom House for sale in New Palam Vihar Ph...
# ...

# %%
df.shape
# Out:
# (1044, 21)

# %%
df.columns
# Out:
# Index(['property_name', 'link', 'society', 'price', 'rate', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'additionalRoom',
#        'address', 'noOfFloor', 'facing', 'agePossession', 'nearbyLocations',
#        'description', 'furnishDetails', 'features', 'rating', 'property_id'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1044 non-null   object
#  1   link             1044 non-null   object
#  2   society          453 non-null    object
#  3   price            968 non-null    object
#  4   rate             1005 non-null   object
#  5   area             1044 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# property_name        0
# link                 0
# society            591
# price               76
# rate                39
# area                 0
# areaWithType        57
# bedRoom             57
# bathroom            57
# balcony             57
# additionalRoom     455
# address             13
# noOfFloor           77
# facing             370
# agePossession       57
# nearbyLocations    131
# description          8
# furnishDetails     301
# features           370
# rating             137
# property_id          8
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(13)

# %%
df = df.drop_duplicates()

# %%
df['property_name'].value_counts()
# Out:
# property_name
# 4 Bedroom House for sale in Sector 109 Gurgaon                                           25
# 4 Bedroom House for sale in Sector 48 Gurgaon                                            20
# 5 Bedroom House for sale in Sector 109 Gurgaon                                           17
# 5 Bedroom House for sale in DLF Phase 2                                                  16
# 5 Bedroom House for sale in DLF Phase 1                                                  15
# 5 Bedroom House for sale in Sector 66 Gurgaon                                            14
# 4 Bedroom House for sale in Nirvana Country                                              13
# 4 Bedroom House for sale in Sector 66 Gurgaon                                            12
# 5 Bedroom House for sale in Nirvana Country                                              10
# 5 Bedroom House for sale in Sector 33 Gurgaon                                             9
# ...

# %%
df['property_name'].str.strip().str.split(' ')
# Out:
# 0       [5, Bedroom, House, for, sale, in, Sector, 70A...
# 1       [5, Bedroom, House, for, sale, in, Sector, 21A...
# 2       [10, Bedroom, House, for, sale, in, Sushant, L...
# 3       [21, Bedroom, House, for, sale, in, Sector, 54...
# 4       [12, Bedroom, House, for, sale, in, Sushant, L...
# 5       [20, Bedroom, House, for, sale, in, Sushant, L...
# 6       [5, Bedroom, House, for, sale, in, Sector, 66,...
# 7       [16, Bedroom, House, for, sale, in, DLF, Phase...
# 8       [6, Bedroom, House, for, sale, in, DLF, Phase, 2]
# 9       [3, Bedroom, House, for, sale, in, Sushant, Lo...
# 10      [4, Bedroom, House, for, sale, in, DLF, Phase, 2]
# 11      [6, Bedroom, House, for, sale, in, DLF, Phase, 4]
# 12      [13, Bedroom, House, for, sale, in, DLF, Phase...
# 13      [5, Bedroom, House, for, sale, in, DLF, Phase, 1]
# 14      [5, Bedroom, House, for, sale, in, B, Block, S...
# 15      [6, Bedroom, House, for, sale, in, New, Palam,...
# ...

# %%
df['property_type'] = df['property_name'].str.strip().str.split(' ').str.get(2)
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_13612\4020023999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['property_type'] = df['property_name'].str.strip().str.split(' ').str.get(2)

# %%
df.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  Bptp Visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...               NaN
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...               NaN
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...               NaN
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %%
df['location'] = df['property_name'].str.strip().str.split('in').str.get(1).str.strip()
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_13612\953546146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location'] = df['property_name'].str.strip().str.split('in').str.get(1).str.strip()

# %%
df = df.drop(columns=['link','property_id'])

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
df['area'].value_counts()
# Out:
# area
# (301 sq.m.) Plot Area            43
# (84 sq.m.) Plot Area             37
# (251 sq.m.) Plot Area            31
# (167 sq.m.) Plot Area            26
# (420 sq.m.) Plot Area            24
# (226 sq.m.) Plot Area            21
# (418 sq.m.) Plot Area            20
# (125 sq.m.) Plot Area            19
# (201 sq.m.) Plot Area            18
# (50 sq.m.) Plot Area             16
# (180 sq.m.) Plot Area            16
# (135 sq.m.) Plot Area            15
# (209 sq.m.) Plot Area            14
# (171 sq.m.) Plot Area            12
# (42 sq.m.) Plot Area             12
# (33 sq.m.) Plot Area             12
# (334 sq.m.) Plot Area            11
# (293 sq.m.) Plot Area            11
# (220 sq.m.) Plot Area            11
# (264 sq.m.) Plot Area            10
# (51 sq.m.) Plot Area              9
# (145 sq.m.) Plot Area             8
# (502 sq.m.) Plot Area             8
# (151 sq.m.) Plot Area             8
# (136 sq.m.) Plot Area             7
# (134 sq.m.) Plot Area             7
# ...

# %%
df['area'].str.split(' ')
# Out:
# 0               [(242, sq.m.), Plot, Area]
# 1                [(50, sq.m.), Plot, Area]
# 2                [(51, sq.m.), Plot, Area]
# 3               [(108, sq.m.), Plot, Area]
# 4                [(52, sq.m.), Plot, Area]
# 5               [(107, sq.m.), Plot, Area]
# 6               [(301, sq.m.), Plot, Area]
# 7               [(418, sq.m.), Plot, Area]
# 8               [(264, sq.m.), Plot, Area]
# 9               [(180, sq.m.), Plot, Area]
# 10              [(125, sq.m.), Plot, Area]
# 11              [(301, sq.m.), Plot, Area]
# 12              [(136, sq.m.), Plot, Area]
# 13              [(420, sq.m.), Plot, Area]
# 14              [(251, sq.m.), Plot, Area]
# 15              [(125, sq.m.), Plot, Area]
# 16              [(334, sq.m.), Plot, Area]
# 17               [(84, sq.m.), Plot, Area]
# 18              [(201, sq.m.), Plot, Area]
# 19              [(268, sq.m.), Plot, Area]
# 20              [(244, sq.m.), Plot, Area]
# 21              [(293, sq.m.), Plot, Area]
# ...

# %%
df['area_in_sqft'] = round((df['area'].str.split(' ').str.get(0).str.replace('(','').str.strip().str.split('-').str.get(0).astype(float))*(10.764),2)

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
df['rate'].value_counts()
# Out:
# rate
# ₹ 22,222/sq.ft.     14
# ₹ 11,111/sq.ft.     11
# ₹ 33,333/sq.ft.     11
# ₹ 10,000/sq.ft.     10
# ₹ 30,556/sq.ft.      6
# ₹ 37,037/sq.ft.      6
# ₹ 31,481/sq.ft.      6
# ₹ 13,333/sq.ft.      6
# ₹ 26,667/sq.ft.      6
# ₹ 26,235/sq.ft.      6
# ₹ 23,148/sq.ft.      5
# ₹ 8,000/sq.ft.       5
# ₹ 9,444/sq.ft.       5
# ₹ 23,333/sq.ft.      5
# ₹ 11,100/sq.ft.      5
# ₹ 8,889/sq.ft.       5
# ₹ 5,000/sq.ft.       5
# ₹ 6,944/sq.ft.       4
# ₹ 35,000/sq.ft.      4
# ₹ 18,889/sq.ft.      4
# ₹ 24,691/sq.ft.      4
# ₹ 27,778/sq.ft.      4
# ₹ 21,605/sq.ft.      4
# ₹ 9,722/sq.ft.       4
# ₹ 25,000/sq.ft.      4
# ₹ 32,407/sq.ft.      4
# ₹ 34,722/sq.ft.      4
# ₹ 10,556/sq.ft.      3
# ₹ 36,111/sq.ft.      3
# ₹ 13,889/sq.ft.      3
# ₹ 33,951/sq.ft.      3
# ₹ 15,625/sq.ft.      3
# ₹ 32,222/sq.ft.      3
# ₹ 29,880/sq.ft.      3
# ₹ 8,333/sq.ft.       3
# ₹ 50,000/sq.ft.      3
# ₹ 11,250/sq.ft.      3
# ₹ 7,500/sq.ft.       3
# ₹ 60,000/sq.ft.      3
# ...

# %%
df['price_per_sqft'] = df['rate'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype(float)

# %%
df.head(1)
# Out:
#                                     property_name           society  \
# 0  5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
#
#         price             rate                   area  \
# 0  5.25 Crore  ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
#
#                   areaWithType     bedRoom     bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)  5 Bedrooms  4 Bathrooms  3+ Balconies
#
#   additionalRoom                                    address noOfFloor  \
# 0   Servant Room  29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors
#
#        facing    agePossession  \
# 0  North-East  0 to 1 Year Old
#
#                                      nearbyLocations  \
# 0  ['Good Earth City Center 2', 'Kunskapsskolan I...
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
#
# ...

# %%
df['price_in_crore'] = round(((df['area_in_sqft'])*(df['price_per_sqft']))/(10000000.0),2)

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
df['property_name'].value_counts()
# Out:
# property_name
# 4 Bedroom House for sale in Sector 109 Gurgaon                                           25
# 4 Bedroom House for sale in Sector 48 Gurgaon                                            20
# 5 Bedroom House for sale in Sector 109 Gurgaon                                           17
# 5 Bedroom House for sale in DLF Phase 2                                                  16
# 5 Bedroom House for sale in DLF Phase 1                                                  15
# 5 Bedroom House for sale in Sector 66 Gurgaon                                            14
# 4 Bedroom House for sale in Nirvana Country                                              13
# 4 Bedroom House for sale in Sector 66 Gurgaon                                            12
# 5 Bedroom House for sale in Nirvana Country                                              10
# 5 Bedroom House for sale in Sector 33 Gurgaon                                             9
# ...

# %%
df['property_name'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bedRoom'] = df['property_name'].str.split('Bedroom').str.get(0).str.strip().astype(int)

# %%
df['bathroom'] = df['bedRoom']

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         5  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)        5         5   2 Balconies
# ...

# %%
df['balcony'].isnull().sum()
# Out:
# np.int64(57)

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3+ Balconies    366
# 2 Balconies     221
# 3 Balconies     161
# No Balcony      118
# 1 Balcony       108
# Name: count, dtype: int64

# %%
df['balcony'] = df['balcony'].fillna('No Balcony')

# %%
df['balcony'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.strip()

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         5      3+
# 1   Plot area 539(50.07 sq.m.)        5         5       2
# ...

# %%
df['additionalRoom'].isnull().sum()
# Out:
# np.int64(453)

# %%
df['additionalRoom'] = df['additionalRoom'].fillna('not available')

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         5      3+
# 1   Plot area 539(50.07 sq.m.)        5         5       2
# ...

# %%
df = df.drop(columns=['price','rate','area'])

# %%
df['society'].isnull().sum()
# Out:
# np.int64(586)

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         5      3+
# 1   Plot area 539(50.07 sq.m.)        5         5       2
# 2       Plot area 61(51 sq.m.)       10        10      3+
# 3  Plot area 129(107.86 sq.m.)       21        21      3+
# 4    Plot area 62(51.84 sq.m.)       12        12      3+
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
# ...

# %%
df.rename(columns={'noOfFloor':'floorNum'},inplace=True)

# %%
df['floorNum'] = df['floorNum'].ffill().str.split(' ').str.get(0).str.strip().astype(int)

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               NaN
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               NaN
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               NaN
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               NaN
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         5      3+
# 1   Plot area 539(50.07 sq.m.)        5         5       2
# 2       Plot area 61(51 sq.m.)       10        10      3+
# 3  Plot area 129(107.86 sq.m.)       21        21      3+
# 4    Plot area 62(51.84 sq.m.)       12        12      3+
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
# ...

# %%
# df['facing'] = df['facing'].ffill()

# %%
df.head(1)
# Out:
#                                     property_name           society  \
# 0  5 Bedroom House for sale in Sector 70A Gurgaon  Bptp Visionnaire
#
#                   areaWithType  bedRoom  bathroom balcony additionalRoom  \
# 0  Plot area 290(242.48 sq.m.)        5         5      3+   Servant Room
#
#                                      address  floorNum      facing  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana         3  North-East
#
#      agePossession                                    nearbyLocations  \
# 0  0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
# ...

# %%
df = df[['society','price_in_crore','price_per_sqft','areaWithType','bedRoom','bathroom','balcony','additionalRoom','address','floorNum','facing','agePossession','nearbyLocations','description','furnishDetails','features','rating','property_type','location','area_in_sqft']]

# %%
df.head()
# Out:
#             society  price_in_crore  price_per_sqft  \
# 0  Bptp Visionnaire            5.24         20115.0
# 1               NaN            5.69        105751.0
# 2               NaN            2.10         38251.0
# 3               NaN            5.01         43066.0
# 4               NaN            3.01         53763.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         5      3+
# 1   Plot area 539(50.07 sq.m.)        5         5       2
# 2       Plot area 61(51 sq.m.)       10        10      3+
# 3  Plot area 129(107.86 sq.m.)       21        21      3+
# 4    Plot area 62(51.84 sq.m.)       12        12      3+
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
# 3                        Servant Room
# 4                              Others
#
# ...

# %%
df.to_csv('house_cleaned.csv',index=False)
