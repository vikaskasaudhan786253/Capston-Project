# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df1 = pd.read_csv('flat_cleaned.csv')
df2 = pd.read_csv('house_cleaned.csv')

# %%
df1 = df1.rename(columns={'area':'area_in_sqft'})

# %%
df1.columns
# Out:
# Index(['society', 'price_in_crore', 'price_per_sqft', 'areaWithType',
#        'bedRoom', 'bathroom', 'balcony', 'additionalRoom', 'address',
#        'floorNum', 'facing', 'agePossession', 'nearbyLocations', 'description',
#        'furnishDetails', 'features', 'rating', 'bhk', 'property_type',
#        'location', 'area_in_sqft', 'totalFloor'],
#       dtype='object')

# %%
df1 = df1[['society', 'price_in_crore', 'price_per_sqft', 'areaWithType',
       'bedRoom', 'bathroom', 'balcony', 'additionalRoom', 'address',
       'floorNum', 'facing', 'agePossession', 'nearbyLocations', 'description',
       'furnishDetails', 'features', 'rating', 'property_type',
       'location', 'area_in_sqft', 'totalFloor', 'bhk']]

# %%
df1.head(1)
# Out:
#                   society  price_in_crore  price_per_sqft  \
# 0  maa bhagwati residency            0.45          5000.0
#
#                      areaWithType  bedRoom  bathroom balcony additionalRoom  \
# 0  Carpet area: 900 (83.61 sq.m.)        2         2       1  not available
#
#                             address  floorNum facing    agePossession  \
# 0  Krishna Colony, Gurgaon, Haryana         4   West  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
#
#                                               rating property_type  location  \
# ...

# %%
df2.head(1)
# Out:
#             society  price_in_crore  price_per_sqft  \
# 0  Bptp Visionnaire            5.24         20115.0
#
#                   areaWithType  bedRoom  bathroom balcony additionalRoom  \
# 0  Plot area 290(242.48 sq.m.)        5         5      3+   Servant Room
#
#                                      address  floorNum      facing  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana         3  North-East
#
#      agePossession                                    nearbyLocations  \
# 0  0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating property_type  \
# ...

# %%
df = pd.concat([df1,df2],ignore_index=True)

# %%
df.shape
# Out:
# (4026, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4026 entries, 0 to 4025
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   society          3440 non-null   object
#  1   price_in_crore   3986 non-null   float64
#  2   price_per_sqft   3986 non-null   float64
#  3   areaWithType     3969 non-null   object
#  4   bedRoom          4026 non-null   int64
#  5   bathroom         4026 non-null   int64
#  6   balcony          4026 non-null   object
#  7   additionalRoom   4026 non-null   object
#  8   address          4007 non-null   object
#  9   floorNum         4026 non-null   int64
#  10  facing           2785 non-null   object
#  11  agePossession    3968 non-null   object
#  12  nearbyLocations  3806 non-null   object
#  13  description      4018 non-null   object
#  14  furnishDetails   2930 non-null   object
#  15  features         3252 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# society             586
# price_in_crore       40
# price_per_sqft       40
# areaWithType         57
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              19
# floorNum              0
# facing             1241
# agePossession        58
# nearbyLocations     220
# description           8
# furnishDetails     1096
# features            774
# rating              465
# property_type         0
# location              0
# area_in_sqft          1
# totalFloor         1031
# bhk                1031
# dtype: int64

# %%
# df['agePossession'] = df['agePossession'].fillna('undefined')

# %%
# df = df.drop(18).reset_index(drop=True)

# %%
# df[df['description'].isnull()]

# %%
# df[df['description'].isnull()].index

# %%
# df = df.drop([3312, 3313, 3314, 3315, 3318, 3319, 3320, 3828]).reset_index(drop=True)

# %%
# df['bhk'] = df['bhk'].fillna('No bkh')

# %%
# df['totalFloor'] = df['totalFloor'].fillna('NA')

# %%
# df['features'] = df['features'].fillna('NA')

# %%
# df['facing'] = df['facing'].fillna('NA')

# %%
# df['address'] = df['address'].fillna('NA')

# %%
# df[df['price_in_crore'].isnull()].isnull().sum()

# %%
# df[df['price_per_sqft'].isnull()].isnull().sum()

# %%
# df[df['areaWithType'].isnull()].isnull().sum()

# %%
# df[df['price_in_crore'].isnull()].index

# %%
# df  = df.drop([3040, 3081, 3082, 3097, 3098, 3108, 3243, 3253, 3254, 3266, 3270, 3271,
#        3277, 3283, 3284, 3292, 3341, 3357, 3370, 3422, 3430, 3433, 3448, 3508,
#        3534, 3570, 3607, 3717, 3725, 3754, 3769, 3777, 3794, 3817, 3892, 3975,
#        3995, 3996]).reset_index(drop=True)

# %%
# df['society'] = df['society'].fillna('independent')

# %%
df[df['areaWithType'].isnull()].isnull().sum()
# Out:
# society             0
# price_in_crore      6
# price_per_sqft      6
# areaWithType       44
# bedRoom             0
# bathroom            0
# balcony             0
# additionalRoom      0
# address             0
# floorNum            0
# facing              0
# agePossession      44
# nearbyLocations     0
# description         0
# furnishDetails     44
# features            0
# rating              6
# property_type       0
# location            0
# area_in_sqft        0
# totalFloor          0
# bhk                 0
# dtype: int64

# %%
df.to_csv('cleaned_v1.csv',index=False)
